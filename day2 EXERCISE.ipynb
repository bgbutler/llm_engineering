# %% [markdown]
# # Welcome to your first assignment!
#
# Instructions are below. Please give this a try, and look in the solutions folder if you get stuck (or feel free to ask me!)

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Just before we get to the assignment --</h2>
#             <span style="color:#f71;">I thought I'd take a second to point you at this page of useful resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # HOMEWORK EXERCISE ASSIGNMENT
#
# Upgrade the day 1 project to summarize a webpage to use an Open Source model running locally via Ollama rather than OpenAI
#
# You'll be able to use this technique for all subsequent projects if you'd prefer not to use paid APIs.
#
# **Benefits:**
# 1. No API charges - open-source
# 2. Data doesn't leave your box
#
# **Disadvantages:**
# 1. Significantly less power than Frontier Model
#
# ## Recap on installation of Ollama
#
# Simply visit [ollama.com](https://ollama.com) and install!
#
# Once complete, the ollama server should already be running locally.
# If you visit:
# [http://localhost:11434/](http://localhost:11434/)
#
# You should see the message `Ollama is running`.
#
# If not, bring up a new Terminal (Mac) or Powershell (Windows) and enter `ollama serve`
# And in another Terminal (Mac) or Powershell (Windows), enter `ollama pull llama3.2`
# Then try [http://localhost:11434/](http://localhost:11434/) again.
#
# If Ollama is slow on your machine, try using `llama3.2:1b` as an alternative. Run `ollama pull llama3.2:1b` from a Terminal or Powershell, and change the code below from `MODEL = "llama3.2"` to `MODEL = "llama3.2:1b"`

# %%
# imports

import requests
from bs4 import BeautifulSoup
from IPython.display import Markdown, display

# %%
# Constants

OLLAMA_API = "http://localhost:11434/api/chat"
HEADERS = {"Content-Type": "application/json"}
MODEL = "llama3.2"

# %%
# Create a messages list using the same format that we used for OpenAI

messages = [
    {"role": "user", "content": "Describe some of the business applications of Generative AI"}
]

# %%
payload = {
        "model": MODEL,
        "messages": messages,
        "stream": False
    }

# %%
# Let's just make sure the model is loaded

# !ollama pull llama3.2
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
# If this doesn't work for any reason, try the 2 versions in the following cells
# And double check the instructions in the 'Recap on installation of Ollama' at the top of this lab
# And if none of that works - contact me!

response = requests.post(OLLAMA_API, json=payload, headers=HEADERS)
print(response.json()['message']['content'])
# Out:
# Generative AI has numerous business applications across various industries, including:
#
# 1. **Content Creation**: Generative AI can generate high-quality content such as articles, blog posts, social media posts, and product descriptions, reducing the need for human writers and editors.
# 2. **Marketing Automation**: Generative AI can create personalized marketing campaigns, recommend products to customers based on their behavior, and optimize ad targeting.
# 3. **Product Design**: Generative AI can design new product concepts, prototypes, and packaging designs, streamlining the product development process.
# 4. **Customer Service Chatbots**: Generative AI-powered chatbots can provide 24/7 customer support, answering common queries and routing complex issues to human representatives.
# 5. **Image Generation**: Generative AI can create high-quality images for advertising, marketing materials, and e-commerce websites, reducing the need for expensive stock photography.
# 6. **Music Composition**: Generative AI can compose music for films, video games, and advertisements, revolutionizing the music industry.
# 7. **Data Analysis**: Generative AI can analyze large datasets, identify patterns, and predict outcomes, helping businesses make data-driven decisions.
# 8. **Predictive Maintenance**: Generative AI can predict equipment failures, optimize maintenance schedules, and reduce downtime in industries such as manufacturing and energy.
# 9. **Personalized Recommendations**: Generative AI can create personalized product recommendations for e-commerce websites, increasing sales and customer engagement.
# 10. **Automated Writing Assistance**: Generative AI can assist writers with research, suggestions, and even full drafts, freeing up human writers to focus on high-level creative work.
#
# Some industries that are particularly well-suited for generative AI include:
#
# 1. **E-commerce**: Generative AI can optimize product listings, recommend products, and create personalized shopping experiences.
# 2. **Finance**: Generative AI can analyze financial data, predict market trends, and identify investment opportunities.
# 3. **Healthcare**: Generative AI can help develop new treatments, diagnose diseases, and personalize patient care plans.
# 4. **Education**: Generative AI can create personalized learning materials, grade assignments, and provide feedback to students.
#
# Overall, generative AI has the potential to revolutionize various business applications by increasing efficiency, reducing costs, and improving customer experiences.

# %% [markdown]
# # Introducing the ollama package
#
# And now we'll do the same thing, but using the elegant ollama python package instead of a direct HTTP call.
#
# Under the hood, it's making the same call as above to the ollama server running at localhost:11434

# %%
import ollama

response = ollama.chat(model=MODEL, messages=messages)
print(response['message']['content'])
# Out:
# Generative AI has numerous business applications across various industries, including:
#
# 1. **Content Creation**: Generative AI can be used to generate high-quality content such as articles, social media posts, product descriptions, and more. This can help businesses save time and resources on content creation.
# 2. **Digital Marketing**: Generative AI can be used to create personalized marketing campaigns, product recommendations, and customer engagement content. It can also help with data analysis and prediction.
# 3. **Data Analysis and Insights**: Generative AI can be used to analyze large datasets, identify patterns, and provide insights that can inform business decisions.
# 4. **Chatbots and Virtual Assistants**: Generative AI can be used to create conversational interfaces for chatbots and virtual assistants, providing customers with personalized support and assistance.
# 5. **Automated Customer Service**: Generative AI can be used to automate customer service processes, such as responding to frequently asked questions, resolving issues, and providing basic support.
# 6. **Product Design and Development**: Generative AI can be used to design and develop new products, such as furniture, clothing, and other consumer goods.
# 7. **Personalization**: Generative AI can be used to create personalized experiences for customers, such as product recommendations, targeted advertising, and customized content.
# 8. **Predictive Maintenance**: Generative AI can be used to predict equipment failures, reducing downtime and increasing efficiency in industries such as manufacturing and transportation.
# 9. **Financial Modeling**: Generative AI can be used to build predictive models of financial outcomes, helping businesses make more informed investment decisions.
# 10. **Supply Chain Optimization**: Generative AI can be used to optimize supply chain operations, including inventory management, logistics, and demand forecasting.
#
# Some specific examples of business applications of Generative AI include:
#
# * **Amazon's Product Recommendations**: Amazon uses Generative AI to generate personalized product recommendations for customers based on their browsing history and purchase behavior.
# * **Google's Search Results**: Google uses Generative AI to improve its search results by generating more relevant and accurate answers to user queries.
# * **IBM's Watson**: IBM's Watson uses Generative AI to analyze large datasets, provide insights, and make predictions in industries such as healthcare and finance.
#
# These are just a few examples of the many business applications of Generative AI. As the technology continues to evolve, we can expect to see even more innovative applications across various industries.

# %% [markdown]
# ## Alternative approach - using OpenAI python library to connect to Ollama

# %%
# There's actually an alternative approach that some people might prefer
# You can use the OpenAI client python library to call Ollama:

from openai import OpenAI
ollama_via_openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')

response = ollama_via_openai.chat.completions.create(
    model=MODEL,
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# Generative AI has numerous business applications across various industries. Here are some examples:
#
# 1. **Content Generation**: Generative AI can create high-quality, unique content such as:
# 	* Blog posts and articles
# 	* Social media posts and profiles
# 	* Product descriptions and copywriting
# 	* Music and audio tracks
# 2. **Product Design and Development**: Generative AI can help with:
# 	* Product design and prototyping
# 	* Image and 3D modeling
# 	* Color palette and texture generation
# 	* Material and texture suggestions
# 3. **Marketing and Advertising**: Generative AI can be used to create:
# 	* Personalized ads and marketing campaigns
# 	* Influencer content and social media posts
# 	* Virtual product demonstrations and experiences
# 4. **Product Recommendations and Personalization**: Generative AI can help with:
# 	* Product recommendation engines
# 	* User profile creation and segmentation
# 	* Content suggestion algorithms
# 5. **Data Analysis and Visualization**: Generative AI can assist in:
# 	* Data imputation and filling missing values
# 	* Feature generation and dimensionality reduction
# 	* Anomaly detection and outlier identification
# 6. **Accessibility and Inclusive Design**: Generative AI can create:
# 	* Personalized audio descriptions for visually impaired users
# 	* Braille text and sign language interpretations
# 	* Accessible website and app interfaces
# 7. **Entertainment and Media Production**: Generative AI can be used to create:
# 	* Music, film, TV show, and video game content
# 	* Virtual characters and avatars
# 	* Interactive stories and experiences
# 8. **Supply Chain Optimization**: Generative AI can help with:
# 	* Supply chain optimization and demand forecasting
# 	* Inventory management and supply chain planning
# 	* Logistics routing and optimization
# 9. **Cybersecurity**: Generative AI can be used to create:
# 	* Predictive models for malware detection and prevention
# 	* Anomaly detection and incident response systems
# 	* Red team simulation and exercise tools
# 10. **Healthcare**: Generative AI can assist with:
# 	* Medical image analysis and diagnostic tool development
# 	* Personalized medicine and treatment recommendations
# 	* Patient data analysis and risk stratification
#
# These examples demonstrate the vast potential of generative AI to transform various industries and business processes.

# %% [markdown]
# ## Are you confused about why that works?
#
# It seems strange, right? We just used OpenAI code to call Ollama?? What's going on?!
#
# Here's the scoop:
#
# The python class `OpenAI` is simply code written by OpenAI engineers that makes calls over the internet to an endpoint.
#
# When you call `openai.chat.completions.create()`, this python code just makes a web request to the following url: "https://api.openai.com/v1/chat/completions"
#
# Code like this is known as a "client library" - it's just wrapper code that runs on your machine to make web requests. The actual power of GPT is running on OpenAI's cloud behind this API, not on your computer!
#
# OpenAI was so popular, that lots of other AI providers provided identical web endpoints, so you could use the same approach.
#
# So Ollama has an endpoint running on your local box at http://localhost:11434/v1/chat/completions
# And in week 2 we'll discover that lots of other providers do this too, including Gemini and DeepSeek.
#
# And then the team at OpenAI had a great idea: they can extend their client library so you can specify a different 'base url', and use their library to call any compatible API.
#
# That's it!
#
# So when you say: `ollama_via_openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')`
# Then this will make the same endpoint calls, but to Ollama instead of OpenAI.

# %% [markdown]
# ## Also trying the amazing reasoning model DeepSeek
#
# Here we use the version of DeepSeek-reasoner that's been distilled to 1.5B.
# This is actually a 1.5B variant of Qwen that has been fine-tuned using synethic data generated by Deepseek R1.
#
# Other sizes of DeepSeek are [here](https://ollama.com/library/deepseek-r1) all the way up to the full 671B parameter version, which would use up 404GB of your drive and is far too large for most!

# %%
# !ollama pull deepseek-r1:1.5b

# %%
# This may take a few minutes to run! You should then see a fascinating "thinking" trace inside <think> tags, followed by some decent definitions

response = ollama_via_openai.chat.completions.create(
    model="deepseek-r1:1.5b",
    messages=[{"role": "user", "content": "Please give definitions of some core concepts behind LLMs: a neural network, attention and the transformer"}]
)

print(response.choices[0].message.content)

# %% [markdown]
# # NOW the exercise for you
#
# Take the code from day1 and incorporate it here, to build a website summarizer that uses Llama 3.2 running locally instead of OpenAI; use either of the above approaches.

# %%
# imports for web scraper

import os
import requests

from bs4 import BeautifulSoup
from IPython.display import Markdown, display

import ollama

# %%
# set constants

MODEL = "llama3.2"

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped
    """
    url: str
    title: str
    text: str

    def __init__(self, url):
        """
        Create this Website object from the given url using the BeautifulSoup library
        """
        self.url = url
        response = requests.get(url, headers = headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        for irrelevant in soup.body(["script", "style", "img", "input"]):
            irrelevant.decompose()
        self.text = soup.body.get_text(separator="\n", strip=True)

# %%
# Let's try one out

site = Website("https://ground.news")
print(site.title)
print(site.text)
# Out:
# Ground News
# Don't Just Read the News, Understand It.
# Get Started
# Browser Extension
# Tuesday, June 24, 2025
# Set Location
# US
# Edition
# Home
# For You
# Local
# Blindspot
# Subscribe
# Login
# Subscribe
# Login
# Israel-Hamas Conflict
# NATO
# Donald Trump
# Artificial Intelligence
# Social Media
# Heatwaves
# War
# Senate
# Infrastructure
# Music
# World Cup
# Education
# Soccer
# News
# Home Page
# Local News
# Blindspot Feed
# International
# Covid-19
# International
# North America
# South America
# Europe
# Asia
# Australia
# Africa
# Trending Internationally
# NATO
# Donald Trump
# Artificial Intelligence
# Social Media
# Heatwaves
# Trending in U.S.
# Israel-Hamas Conflict
# Heatwaves
# Donald Trump
# US Politics
# US Immigration
# Trending in U.K.
# Israel-Hamas Conflict
# UK Economy
# Manchester United
# Premier League
# Arsenal FC
# Trending Topics
# NATO
# Donald Trump
# Artificial Intelligence
# Social Media
# Israel-Hamas Conflict
# Company
# About
# History
# Mission
# Blog
# Testimonials
# Group Subscriptions
# Subscribe
# Gift
# Free Trial
# Careers
# Affiliates
# Merch
# Help
# Help Center
# FAQ
# Contact Us
# For Educators/Libraries
# Media Bias Ratings
# Ownership and Factuality Ratings
# Referral Code
# News Sources
# Topics
# Tools
# App
# Browser Extension
# Daily Newsletter
# Blindspot Report Newsletter
# Burst Your Bubble Newsletter
# Timelines
# Gift
# Privacy Policy
# Manage Cookies
# Terms and Conditions
# ©
# 2025
# Snapwise Inc
# News
# For You
# Search
# Blindspot
# Local
# Daily Briefing
# 11
# stories •
# 584
# articles •
# 11
# m read
# 11
# stories •
# 584
# articles •
# 11
# m read
# Georgia Jails Three Opposition Politicians in Intensifying Crackdown
# Critics says barring jailed leaders from office underscores democratic backsliding, stalling Georgia's EU accession.
# +
# Israel-Iran conflict fuels misinformation
# ;
# Deputy Prime Minister faces corruption suspicion
# ;
# 120 children kidnapped in Mozambique
# ;
# and more.
# Top News Stories
# Trump says Israel-Iran ceasefire is in effect after deal initially faltered
# 52
# % Center coverage:
# 172
# sources
# Iranian official tells CNN Tehran never received ceasefire proposal
# 50
# % Right coverage:
# 38
# sources
# Supreme Court allows Trump to restart swift deportation of migrants away from their home countries
# 44
# % Center coverage:
# 145
# sources
# Donald Trump confirms Iran warned ahead of Qatar military base attack
# 36
# % Right coverage:
# 87
# sources
# Iran says it launched attack on US forces at Qatar’s Al Udeid Air Base
# 37
# % Right coverage:
# 76
# sources
# Top News
# Jun 24, 2025
# Early US intelligence report suggests US strikes only set back Iran’s nuclear program by months: Report
# Early US intelligence report suggests US strikes only set back Iran’s nuclear program by months: Report
# Left 32%
# Center 54%
# R 14%
# Early US intelligence report suggests US strikes only set back Iran’s nuclear program by months: Report
# 54
# % Center coverage:
# 65
# sources
# Donald Trump
# · United States
# Trump urges GOP to quickly pass his megabill: No vacation until it’s done
# 55
# % Center coverage:
# 20
# sources
# Crime
# · Texas
# Karmelo Anthony Indicted in Frisco Track Meet Stabbing Death of Austin Metcalf, Officials Say
# 60
# % Center coverage:
# 20
# sources
# Lisa Murkowski
# · Alaska
# Murkowski says she has thought about switching to Democratic caucus
# 55
# % Right coverage:
# 22
# sources
# Donald Trump
# · United States
# Trump Backs Away From Leadership Turnover in Iran: ‘Regime Change Takes Chaos’
# 38
# % Right coverage:
# 37
# sources
# Republican Party
# · United States
# Senate Rulekeeper Blocks Public Lands Sales — Including in Colorado — From Republican Budget Bill
# Coverage:
# 6
# sources
# Donald Trump
# · Gaza
# Trump Administration Authorizes $30 Million for Israeli-Backed Group Distributing Food in Gaza
# 70
# % Center coverage:
# 13
# sources
# Donald Trump
# · United States
# Trump urges GOP to quickly pass his megabill: No vacation until it’s done
# 55
# % Center coverage:
# 20
# sources
# Crime
# · Texas
# Karmelo Anthony Indicted in Frisco Track Meet Stabbing Death of Austin Metcalf, Officials Say
# 60
# % Center coverage:
# 20
# sources
# Daily Briefing
# 11
# stories •
# 584
# articles •
# 11
# m read
# 11
# stories •
# 584
# articles •
# 11
# m read
# Georgia Jails Three Opposition Politicians in Intensifying Crackdown
# Critics says barring jailed leaders from office underscores democratic backsliding, stalling Georgia's EU accession.
# +
# Israel-Iran conflict fuels misinformation
# ;
# Deputy Prime Minister faces corruption suspicion
# ;
# 120 children kidnapped in Mozambique
# ;
# and more.
# Lisa Murkowski
# · Alaska
# Murkowski says she has thought about switching to Democratic caucus
# 55
# % Right coverage:
# 22
# sources
# Donald Trump
# · United States
# Trump Backs Away From Leadership Turnover in Iran: ‘Regime Change Takes Chaos’
# 38
# % Right coverage:
# 37
# sources
# Republican Party
# · United States
# Senate Rulekeeper Blocks Public Lands Sales — Including in Colorado — From Republican Budget Bill
# Coverage:
# 6
# sources
# Donald Trump
# · Gaza
# Trump Administration Authorizes $30 Million for Israeli-Backed Group Distributing Food in Gaza
# 70
# % Center coverage:
# 13
# sources
# Israel-Iran Conflict
# · Israel
# Trump says Israel-Iran ceasefire is in effect after deal initially faltered
# 52
# % Center coverage:
# 172
# sources
# Israel-Iran Conflict
# · United States
# Iranian official tells CNN Tehran never received ceasefire proposal
# 50
# % Right coverage:
# 38
# sources
# US Immigration
# · United States
# Supreme Court allows Trump to restart swift deportation of migrants away from their home countries
# 44
# % Center coverage:
# 145
# sources
# Israel-Iran Conflict
# · Iran
# Donald Trump confirms Iran warned ahead of Qatar military base attack
# 36
# % Right coverage:
# 87
# sources
# Israel-Iran Conflict
# · Doha
# Iran says it launched attack on US forces at Qatar’s Al Udeid Air Base
# 37
# % Right coverage:
# 76
# sources
# My News Bias
# Linda B. (Sample user)
# 35
# Stories ·
# 10
# Articles
# L 33%
# C 47%
# R 20%
# See the demo
# Jun 24, 2025
# Stories disproportionately covered by one side of the political spectrum.
# Learn more about political bias in news coverage.
# Low coverage from Left Sources
# 6h ago
# US arrests 11 Iranians in US illegally, Homeland Security says
# No coverage from Right Sources
# 47m ago
# Garcia secures top Democratic seat on powerful Oversight Committee
# 100% of Sources are High Factuality
# View Blindspot Feed
# US Politics
# · California
# Emhoff lands USC law school job amid ‘difficult moment for the legal community’
# 67
# % Center coverage:
# 6
# sources
# Walmart
# · United States
# Retail Giant Reaches $10 Million Deal to End Consumer Fraud Complaint
# 72
# % Center coverage:
# 7
# sources
# US Politics
# · United States
# Senate parliamentarian rejects offshore oil, gas drilling provisions in GOP megabill
# 38
# % Right coverage:
# 8
# sources
# US Politics
# · California
# Man charged with supplying chemicals to Palm Springs fertility clinic bomber dies in custody
# 51
# % Center coverage:
# 39
# sources
# US Politics
# · California
# Emhoff lands USC law school job amid ‘difficult moment for the legal community’
# 67
# % Center coverage:
# 6
# sources
# Walmart
# · United States
# Retail Giant Reaches $10 Million Deal to End Consumer Fraud Complaint
# 72
# % Center coverage:
# 7
# sources
# US Politics
# · United States
# Senate parliamentarian rejects offshore oil, gas drilling provisions in GOP megabill
# 38
# % Right coverage:
# 8
# sources
# US Politics
# · California
# Man charged with supplying chemicals to Palm Springs fertility clinic bomber dies in custody
# 51
# % Center coverage:
# 39
# sources
# Daily Local News
# Discover stories and media bias happening right in your city.
# Submit
# Set Location
# Latest Stories
# Heatwaves
# · New York
# Central Park hits temp record last seen on this date in 1888 as heat wave hits eastern US
# 80
# % Center coverage:
# 15
# sources
# US Politics
# · United States
# House torpedoes Rep. Al Green’s effort to impeach Trump over Iran strikes
# 42
# % Center coverage:
# 48
# sources
# Mark Rutte
# · United States
# NATO Secretary General Congratulates Trump on Iran Air Strikes
# 41
# % Center coverage:
# 51
# sources
# US Crime
# · Dallas
# State Fair of Texas Shooter Pleads Guilty, Sentenced
# 100
# % Center coverage:
# 9
# sources
# Josh Shapiro
# · Pennsylvania
# Pennsylvania Gov. Josh Shapiro Reaffirmed the State Would Provide No Funding for Any New Sports Arenas
# 51
# % Left coverage:
# 35
# sources
# Science
# · China
# Scientists Discover 20 New Bat Viruses in Yunnan, Including Hendra and Nipah Relatives
# 46
# % Center coverage:
# 11
# sources
# Latest Stories
# US Politics
# · California
# Emhoff lands USC law school job amid ‘difficult moment for the legal community’
# 67
# % Center coverage:
# 6
# sources
# Walmart
# · United States
# Retail Giant Reaches $10 Million Deal to End Consumer Fraud Complaint
# 72
# % Center coverage:
# 7
# sources
# US Politics
# · United States
# Senate parliamentarian rejects offshore oil, gas drilling provisions in GOP megabill
# 38
# % Right coverage:
# 8
# sources
# US Politics
# · California
# Man charged with supplying chemicals to Palm Springs fertility clinic bomber dies in custody
# 51
# % Center coverage:
# 39
# sources
# Israel-Hamas Conflict News
# Follow
# Read More
# Latest
# Israel-Hamas Conflict News
# More than 100 people on Canadian chartered flight leaving Middle East tonight: Anand
# Left 50%
# Center 30%
# R 20%
# More than 100 people on Canadian chartered flight leaving Middle East tonight: Anand
# Read more
# Israel-Hamas Conflict
# Israel-Hamas Conflict Blindspots
# No coverage from Left Sources
# 7h ago
# Phenomenal Achievements, Campaign Against Iran Not over, Zamir Says
# No coverage from Right Sources
# 14h ago
# At least 25 people killed after Israeli forces open fire near aid trucks in Gaza: Report
# Blindspot
# Get the weekly Blindspot report sent to your inbox and stay up to date with your bias blindspot.
# Subscribe
# Latest Stories
# Heatwaves
# · New York
# Central Park hits temp record last seen on this date in 1888 as heat wave hits eastern US
# 80
# % Center coverage:
# 15
# sources
# US Politics
# · United States
# House torpedoes Rep. Al Green’s effort to impeach Trump over Iran strikes
# 42
# % Center coverage:
# 48
# sources
# Mark Rutte
# · United States
# NATO Secretary General Congratulates Trump on Iran Air Strikes
# 41
# % Center coverage:
# 51
# sources
# US Crime
# · Dallas
# State Fair of Texas Shooter Pleads Guilty, Sentenced
# 100
# % Center coverage:
# 9
# sources
# Josh Shapiro
# · Pennsylvania
# Pennsylvania Gov. Josh Shapiro Reaffirmed the State Would Provide No Funding for Any New Sports Arenas
# 51
# % Left coverage:
# 35
# sources
# Science
# · China
# Scientists Discover 20 New Bat Viruses in Yunnan, Including Hendra and Nipah Relatives
# 46
# % Center coverage:
# 11
# sources
# Similar News Topics
# Israel-Hamas Conflict
# Heatwaves
# Donald Trump
# US Politics
# Senate
# US Economy
# US Immigration
# US Politics News
# Follow
# Read More
# Latest
# US Politics News
# 5 Democratic senators protest Trump Kennedy Center takeover with gay pride concert
# Left 42%
# Center 25%
# Right 33%
# 5 Democratic senators protest Trump Kennedy Center takeover with gay pride concert
# Read more
# US Politics
# US Politics Blindspots
# Low coverage from Left Sources
# 7h ago
# Former Astronaut Terry Virts Launches Democratic Bid for U.S. Senate in Texas
# Low coverage from Right Sources
# 6h ago
# Texas, Oklahoma and Nevada make changes to lure business amid Delaware’s ‘Dexit’ concern
# Blindspot
# Get the weekly Blindspot report sent to your inbox and stay up to date with your bias blindspot.
# Subscribe
# Latest News Stories
# Heatwaves
# · New York
# Central Park hits temp record last seen on this date in 1888 as heat wave hits eastern US
# 80
# % Center coverage:
# 15
# sources
# US Politics
# · United States
# House torpedoes Rep. Al Green’s effort to impeach Trump over Iran strikes
# 42
# % Center coverage:
# 48
# sources
# Mark Rutte
# · United States
# NATO Secretary General Congratulates Trump on Iran Air Strikes
# 41
# % Center coverage:
# 51
# sources
# US Crime
# · Dallas
# State Fair of Texas Shooter Pleads Guilty, Sentenced
# 100
# % Center coverage:
# 9
# sources
# Josh Shapiro
# · Pennsylvania
# Pennsylvania Gov. Josh Shapiro Reaffirmed the State Would Provide No Funding for Any New Sports Arenas
# 51
# % Left coverage:
# 35
# sources
# Science
# · China
# Scientists Discover 20 New Bat Viruses in Yunnan, Including Hendra and Nipah Relatives
# 46
# % Center coverage:
# 11
# sources
# Tampa Bay Rays
# · United States
# Dominican prosecutors in Wander Franco trial seek 5-year prison sentence
# 48
# % Center coverage:
# 41
# sources
# Ron DeSantis
# · Florida
# DeSantis Signs Condo Reform Legislation in Clearwater
# 72
# % Center coverage:
# 14
# sources
# Benjamin Netanyahu
# · Gaza
# Video Does Not Show Iran Attack on Ben Gurion Airport – Full Fact
# 48
# % Center coverage:
# 42
# sources
# Amazon
# · Cape Canaveral
# Second Batch of Amazon Satellites Launched by Colorado Rocketeer
# 87
# % Center coverage:
# 16
# sources
# Species
# · United States
# 500 bird species face extinction within the next century, researchers warn
# 48
# % Center coverage:
# 19
# sources
# More stories
# Trump urges GOP to quickly pass his megabill: No vacation until it’s done
# Trump urges GOP to quickly pass his megabill: No vacation until it’s done
# 10%
# Center 55%
# Right 35%
# Trump urges GOP to quickly pass his megabill: No vacation until it’s done
# 55
# % Center coverage:
# 20
# sources
# See every side of every news story.
# Read the news from multiple perspectives. See through media bias with reliable news from local and international sources
# Get Started
# As featured on
# The Hindu
# ·
# India
# Israel-Iran ceasefire is in effect, declares Trump, after rebuking both sides
# CTV News
# ·
# Canada
# Trump says Israel-Iran ceasefire ‘in effect’ after blaming both countries for violations
# NDTV
# ·
# New Delhi
# Trump on Iran-Israel Ceasefire | Truce Tumbles, Will Iran-Israel Hold Ceasefire?
# LEFT
# CENTER
# RIGHT
# 2
# /
# 244
# sources
# Read more
# As featured on

# %%
# Define our system prompt - you can experiment with this later, changing the last sentence to 'Respond in markdown in Spanish."

system_prompt = "You are an assistant that analyzes the contents of a website \
and provides a short summary, ignoring text that might be navigation related. \
Respond in markdown."

# %%
def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_for(website)}
    ]

# %%
# And now: call the Ollama function instead of OpenAI in previous example

def summarize(url):
    website = Website(url)
    messages = messages_for(website)
    response = ollama.chat(model=MODEL, messages=messages)
    return response['message']['content']

# %%
# A function that writes a User Prompt that asks for summaries of websites:

def user_prompt_for(website):
    user_prompt = f"You are looking at a website titled {website.title}"
    user_prompt += "\nThe contents of this website is as follows; \
please provide a short summary of this website in markdown. \
If it includes news or announcements, then summarize these too.\n\n"
    user_prompt += website.text
    return user_prompt

# %%
# test it again
summarize("https://ground.news")
# Out:
# '**Ground News Summary**\n===============\n\n### Overview\n\nGround News is a website that provides news and information on various topics. The website has a section for local news, international news, US news, politics, crime, science, entertainment, and more.\n\n### Key Topics\n\n*   **Israel-Hamas Conflict**: The website provides extensive coverage of the Israel-Hamas conflict, including news articles, analysis, and expert opinions.\n*   **US Politics**: Ground News covers various aspects of US politics, including news on the White House, Congress, Senate, and elections.\n*   **Crime**: The website reports on crime-related news in the United States, including stories about police investigations, arrests, and court cases.\n\n### Bias\n\nThe website claims to provide "unbiased" news, but an analysis of the bias reveals that the articles may have a slight leaning towards one side or another.\n\n### Key Articles\n\n*   **Trump says Israel-Iran ceasefire is in effect**: In this article, Trump declares that the Israel-Iran ceasefire is in effect after blaming both countries for violations.\n*   **Georgia Jails Three Opposition Politicians**: This article reports on the jailing of three opposition politicians in Georgia and their reactions to the move.\n\n### Social Media\n\nGround News has a presence on social media platforms, including Twitter, Facebook, and Instagram.'

# %%
# make it look clean

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://edwarddonner.com")
# Out:
# # Summary of Edward Donner's Website
#
# ## Overview
#
# The website is owned by Edward Donner, a co-founder and CTO of Nebula.io, an AI company applying AI to help people discover their potential. The site appears to be a personal blog showcasing his interests in artificial intelligence, machine learning, and talent management.
#
# ## Recent News and Announcements
#
# - **May 28, 2025**: "Connecting my courses – become an LLM expert and leader" (promoting online courses)
# - **May 18, 2025**: "2025 AI Executive Briefing" (announcing a briefing event)
# - **April 21, 2025**: No announcement mentioned
# - **January 23, 2025**: "The Complete Agentic AI Engineering Course" (promoting an online course)
#
# ## Content
#
# - The website features Edward Donner's personal story and his experiences as the founder of Nebula.io.
# - He mentions his interests in DJing, electronic music production, and hacker news.
# - There is no detailed information about the company Nebula.io or its products on this site.
#
# ## Contact Information
#
# - Email: [ed at] edwarddonner [dot] com
# - Website: www.edwarddonner.com
# - Social media links (LinkedIn, Twitter, Facebook)
